# %%
# imports
import requests
import os 
import pandas as pd
import json
import pprint
import sqlite3

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) with the location of your choice

# %%
# Set the key
fsq_api_key = os.environ['FOURSQUARE_API_KEY']

# %%
# Set the url and parameters that will be used in our request
base_url = 'https://api.foursquare.com/v3/places/search'
radius = 1000
ll = '44.232344187881836%2C-76.48559630147832' # This is the latitude/longitude for Kingston Centre in Kingston, ON, replaced comma with '%2C
limit = 50 # This is the maximum number of entries per request
fields = 'rating%2Cprice%2Cpopularity%2Cname%2Cdistance%2Clocation%2Ccategories'
params = f'?ll={ll}&radius={radius}&fields={fields}&limit={limit}'

# I did not specify a venue type (e.g. 'bar') to get all bars, restaurants and POIs in this radius 
# Combine  
url = base_url+params

# %%
# get request
headers = {
    "accept": "application/json",
    "Authorization": fsq_api_key
}

response = requests.get(url, headers=headers)

# %%
# check response status
response.status_code
# Out:
# 200

# %%
# save the response as a json file to prevent from sending repeated requests

# !!! DO NOT RUN OR IT WILL OVERWRITE THE SAVED FILE !!! 

#with open('fsq_response.json', 'w') as f:
#    f.write(response.text)

# %% [markdown]
# Parse through the response to get the POI details you want (rating, name, location, etc)

# %%
# let's now work only with our fsq_response.txt file to avoid sending unnecessary requests
with open('fsq_response.json') as f:
    fsq_data = json.load(f)
pprint.pprint(fsq_data)
# Out:
# {'context': {'geo_bounds': {'circle': {'center': {'latitude': 44.232344187881836,
#                                                   'longitude': -76.48559630147832},
#                                        'radius': 1000}}},
#  'results': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#                                        'suffix': '.png'},
#                               'id': 17089,
#                               'name': 'Gift Store'}],
#               'distance': 85,
#               'location': {'address': '165 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'btw Wellington & King',
#                            'formatted_address': '165 Princess St (btw '
#                                                 'Wellington & King), Kingston '
#                                                 'ON K7L 1A9',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1A9',
#                            'region': 'ON'},
#               'name': 'Minotaur Games & Gifts',
#               'popularity': 0.8620689655172413,
#               'rating': 8.4},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/discountstore_',
#                                        'suffix': '.png'},
#                               'id': 17034,
#                               'name': 'Discount Store'}],
#               'distance': 64,
#               'location': {'address': '176 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'Montreal Street',
#                            'formatted_address': '176 Princess St (Montreal '
#                                                 'Street), Kingston ON K7L 1B1',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1B1',
#                            'region': 'ON'},
#               'name': 'Dollarama',
#               'popularity': 0.934592227695676,
#               'rating': 7.3},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#                                        'suffix': '.png'},
#                               'id': 13002,
#                               'name': 'Bakery'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#                                        'suffix': '.png'},
#                               'id': 13034,
#                               'name': 'Café'}],
#               'distance': 134,
#               'location': {'address': '166 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'Bagot Street',
#                            'formatted_address': '166 Princess St (Bagot '
#                                                 'Street), Kingston ON K7L 1B1',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Kingston'],
#                            'postcode': 'K7L 1B1',
#                            'region': 'ON'},
#               'name': 'Crave Coffee House & Bakery',
#               'popularity': 0.9579912424740011,
#               'price': 1,
#               'rating': 8.0},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/frozenyogurt_',
#                                        'suffix': '.png'},
#                               'id': 13044,
#                               'name': 'Frozen Yogurt Shop'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'distance': 123,
#               'location': {'address': '241 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'at Sydenham St',
#                            'formatted_address': '241 Princess St (at Sydenham '
#                                                 'St), Kingston ON K7L 1B3',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Queens'],
#                            'postcode': 'K7L 1B3',
#                            'region': 'ON'},
#               'name': "Menchie's",
#               'popularity': 0.8155446086480569,
#               'price': 1,
#               'rating': 7.7},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#                                        'suffix': '.png'},
#                               'id': 13029,
#                               'name': 'Brewery'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'distance': 199,
#               'location': {'address': '275 Princess St',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '275 Princess St, Kingston ON '
#                                                 'K7L 1B4',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Kingston'],
#                            'postcode': 'K7L 1B4',
#                            'region': 'ON'},
#               'name': 'Stone City Ales',
#               'popularity': 0.9329501915708812,
#               'price': 2,
#               'rating': 9.0},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#                                        'suffix': '.png'},
#                               'id': 13034,
#                               'name': 'Café'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_',
#                                        'suffix': '.png'},
#                               'id': 13165,
#                               'name': 'German Restaurant'}],
#               'distance': 90,
#               'location': {'address': '170 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'at Montreal St',
#                            'formatted_address': '170 Princess St (at Montreal '
#                                                 'St), Kingston ON K7L 1B1',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1B1',
#                            'region': 'ON'},
#               'name': 'Amadeus Cafe',
#               'popularity': 0.9239189928845101,
#               'price': 2,
#               'rating': 6.9},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#                                        'suffix': '.png'},
#                               'id': 13276,
#                               'name': 'Sushi Restaurant'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#                                        'suffix': '.png'},
#                               'id': 13289,
#                               'name': 'Korean Restaurant'}],
#               'distance': 189,
#               'location': {'address': '269 Princess St',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '269 Princess St, Kingston ON '
#                                                 'K7L 1B4',
#                            'locality': 'Kingston',
#                            'postcode': 'K7L 1B4',
#                            'region': 'ON'},
#               'name': 'Hwa-Ki',
#               'popularity': 0.29064039408866993,
#               'price': 2,
#               'rating': 7.9},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#                                        'suffix': '.png'},
#                               'id': 10026,
#                               'name': 'Indie Movie Theater'}],
#               'distance': 215,
#               'location': {'address': '120 Princess St',
#                            'country': 'CA',
#                            'cross_street': '2nd Floor',
#                            'formatted_address': '120 Princess St (2nd Floor), '
#                                                 'Kingston ON K7L 5M6',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 5M6',
#                            'region': 'ON'},
#               'name': 'The Screening Room',
#               'popularity': 0.8735632183908046,
#               'rating': 8.3},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#                                        'suffix': '.png'},
#                               'id': 13034,
#                               'name': 'Café'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#                                        'suffix': '.png'},
#                               'id': 13035,
#                               'name': 'Coffee Shop'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'distance': 149,
#               'location': {'address': '251 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'Sydenham Street',
#                            'formatted_address': '251 Princess St (Sydenham '
#                                                 'Street), Kingston ON K7L 1B4',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Kingston'],
#                            'postcode': 'K7L 1B4',
#                            'region': 'ON'},
#               'name': "Balzac's Coffee",
#               'popularity': 0.9407498631636563,
#               'price': 1,
#               'rating': 7.3},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#                                        'suffix': '.png'},
#                               'id': 13049,
#                               'name': 'Diner'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#                                        'suffix': '.png'},
#                               'id': 13064,
#                               'name': 'Pizzeria'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#                                        'suffix': '.png'},
#                               'id': 13177,
#                               'name': 'Greek Restaurant'}],
#               'distance': 82,
#               'location': {'address': '167 Princess St',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '167 Princess St, Kingston ON '
#                                                 'K7L 1A9',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1A9',
#                            'region': 'ON'},
#               'name': 'Grecos Grill & Wine Bar',
#               'popularity': 0.9131089217296113,
#               'price': 2,
#               'rating': 6.6},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#                                        'suffix': '.png'},
#                               'id': 17117,
#                               'name': 'Sporting Goods Retail'}],
#               'distance': 189,
#               'location': {'address': '270 Princess St',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '270 Princess St, Kingston ON '
#                                                 'K7L 1B5',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1B5',
#                            'region': 'ON'},
#               'name': 'Lululemon Athletica',
#               'popularity': 0.9314449917898193,
#               'rating': 7.6},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#                                        'suffix': '.png'},
#                               'id': 17035,
#                               'name': 'Drugstore'}],
#               'distance': 163,
#               'location': {'address': '136 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'at Bagot St',
#                            'formatted_address': '136 Princess St (at Bagot '
#                                                 'St), Kingston ON K7L 1A7',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1A7',
#                            'region': 'ON'},
#               'name': 'Shoppers Drug Mart',
#               'popularity': 0.972495894909688,
#               'rating': 7.2},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#                                        'suffix': '.png'},
#                               'id': 17043,
#                               'name': 'Clothing Store'}],
#               'distance': 27,
#               'location': {'address': '207 Princess St',
#                            'country': 'CA',
#                            'formatted_address': '207 Princess St, Kingston ON '
#                                                 'K7L 1B3',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1B3',
#                            'region': 'ON'},
#               'name': 'Urban Outfitters',
#               'popularity': 0.9088669950738916,
#               'rating': 5.8},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13000,
#                               'name': 'Dining and Drinking'}],
#               'distance': 222,
#               'location': {'address': '281 Princess St',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '281 Princess St, Kingston ON '
#                                                 'K7L 1B4',
#                            'locality': 'Kingston',
#                            'postcode': 'K7L 1B4',
#                            'region': 'ON'},
#               'name': 'NORTHSIDE espresso + kitchen',
#               'popularity': 0.8457854406130269,
#               'price': 1,
#               'rating': 7.6},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'distance': 281,
#               'location': {'address': '93 Princess St',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '93 Princess St, Kingston ON '
#                                                 'K7L 1A6',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1A6',
#                            'region': 'ON'},
#               'name': "Harper's",
#               'popularity': 0.8856048166392994,
#               'price': 2,
#               'rating': 8.3},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#                                        'suffix': '.png'},
#                               'id': 11057,
#                               'name': 'Caterer'}],
#               'distance': 222,
#               'location': {'address': '111 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'btwn Bagot St & Wellington St',
#                            'formatted_address': '111 Princess St (btwn Bagot '
#                                                 'St & Wellington St), Kingston '
#                                                 'ON K7L 1A8',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1A8',
#                            'region': 'ON'},
#               'name': 'Golden Rooster Delicatessen',
#               'popularity': 0.942391899288451,
#               'price': 1,
#               'rating': 7.5},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13068,
#                               'name': 'American Restaurant'}],
#               'distance': 111,
#               'location': {'address': '240 Princess St',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '240 Princess St, Kingston ON '
#                                                 'K7L 1B2',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1B2',
#                            'region': 'ON'},
#               'name': 'Copper Penny',
#               'popularity': 0.9038040503557745,
#               'price': 2,
#               'rating': 6.5},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#                                        'suffix': '.png'},
#                               'id': 10004,
#                               'name': 'Art Gallery'}],
#               'distance': 30,
#               'location': {'address': '198 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'Montreal Street',
#                            'formatted_address': '198 Princess St (Montreal '
#                                                 'Street), Kingston ON K7L 1B2',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1B2',
#                            'region': 'ON'},
#               'name': 'Kingston Frameworks',
#               'popularity': 0.8357963875205254},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#                                        'suffix': '.png'},
#                               'id': 19014,
#                               'name': 'Hotel'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#                                        'suffix': '.png'},
#                               'id': 19016,
#                               'name': 'Lodge'}],
#               'distance': 33,
#               'location': {'address': '46 Montreal St',
#                            'country': 'CA',
#                            'formatted_address': '46 Montreal St, Kingston ON '
#                                                 'K7K 3E6',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7K 3E6',
#                            'region': 'ON'},
#               'name': 'Plaza Hotel',
#               'popularity': 0.7837985769020251,
#               'price': 3},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#                                        'suffix': '.png'},
#                               'id': 13276,
#                               'name': 'Sushi Restaurant'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#                                        'suffix': '.png'},
#                               'id': 13289,
#                               'name': 'Korean Restaurant'}],
#               'distance': 217,
#               'location': {'address': '120 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'at Wellington St.',
#                            'formatted_address': '120 Princess St (at '
#                                                 'Wellington St.), Kingston ON '
#                                                 'K7L 5M6',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Kingston'],
#                            'postcode': 'K7L 5M6',
#                            'region': 'ON'},
#               'name': 'Ta Ke Sushi',
#               'popularity': 0.22099069512862615,
#               'price': 3,
#               'rating': 7.3},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#                                        'suffix': '.png'},
#                               'id': 13035,
#                               'name': 'Coffee Shop'}],
#               'distance': 275,
#               'location': {'address': '95 Princess St',
#                            'address_extended': '# 2',
#                            'country': 'CA',
#                            'cross_street': 'at Wellington St',
#                            'formatted_address': '95 Princess St (at Wellington '
#                                                 'St), Kingston ON K7L 1A6',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1A6',
#                            'region': 'ON'},
#               'name': 'Starbucks',
#               'popularity': 0.9429392446633826,
#               'price': 1,
#               'rating': 7.9},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#                                        'suffix': '.png'},
#                               'id': 17119,
#                               'name': 'Bicycle Store'}],
#               'distance': 49,
#               'location': {'address': '332A Barrie St',
#                            'country': 'CA',
#                            'cross_street': 'btw Princess & Queen',
#                            'formatted_address': '332A Barrie St (btw Princess '
#                                                 '& Queen), Kingston ON K7K 3T1',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Queens'],
#                            'postcode': 'K7K 3T1',
#                            'region': 'ON'},
#               'name': 'Racquet Science',
#               'popularity': 0.180623973727422},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#                                        'suffix': '.png'},
#                               'id': 13314,
#                               'name': 'New American Restaurant'}],
#               'distance': 77,
#               'location': {'address': '226 Princess St',
#                            'country': 'CA',
#                            'formatted_address': '226 Princess St, Kingston ON '
#                                                 'K7L 1B2',
#                            'locality': 'Kingston',
#                            'postcode': 'K7L 1B2',
#                            'region': 'ON'},
#               'name': "Megalo's Restaurants",
#               'popularity': 0.9066776135741653,
#               'price': 2,
#               'rating': 5.9},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#                                        'suffix': '.png'},
#                               'id': 10032,
#                               'name': 'Night Club'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#                                        'suffix': '.png'},
#                               'id': 13009,
#                               'name': 'Cocktail Bar'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'distance': 52,
#               'location': {'address': '184 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'Montreal St.',
#                            'formatted_address': '184 Princess St (Montreal '
#                                                 'St.), Kingston ON K7L 1B1',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Kingston'],
#                            'postcode': 'K7L 1B1',
#                            'region': 'ON'},
#               'name': 'Union Kitchen + Cocktails',
#               'popularity': 0.925424192665572,
#               'price': 3},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#                                        'suffix': '.png'},
#                               'id': 13099,
#                               'name': 'Chinese Restaurant'}],
#               'distance': 54,
#               'location': {'address': '185 Princess St',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '185 Princess St, Kingston ON '
#                                                 'K7L 1A9',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Kingston'],
#                            'postcode': 'K7L 1A9',
#                            'region': 'ON'},
#               'name': 'Northern Chinese Barbeque',
#               'popularity': 0.8854679802955665,
#               'price': 1},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13068,
#                               'name': 'American Restaurant'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#                                        'suffix': '.png'},
#                               'id': 13072,
#                               'name': 'Asian Restaurant'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#                                        'suffix': '.png'},
#                               'id': 13352,
#                               'name': 'Thai Restaurant'}],
#               'distance': 94,
#               'location': {'address': '161 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'Bagot St',
#                            'formatted_address': '161 Princess St (Bagot St), '
#                                                 'Kingston ON K7L 1A9',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1A9',
#                            'region': 'ON'},
#               'name': 'Mango Thai & Pan-Asian Cuisine',
#               'popularity': 0.8700054734537493,
#               'price': 2,
#               'rating': 6.0},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tattoos_',
#                                        'suffix': '.png'},
#                               'id': 11075,
#                               'name': 'Tattoo Parlor'}],
#               'distance': 59,
#               'location': {'address': '159 Queen St',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '159 Queen St, Kingston ON K7K '
#                                                 '1A9',
#                            'locality': 'Kingston',
#                            'postcode': 'K7K 1A9',
#                            'region': 'ON'},
#               'name': 'True North Tattoo',
#               'popularity': 0.8648056923918993},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#                                        'suffix': '.png'},
#                               'id': 13064,
#                               'name': 'Pizzeria'}],
#               'distance': 299,
#               'location': {'address': '91 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'Wellington Street',
#                            'formatted_address': '91 Princess St (Wellington '
#                                                 'Street), Kingston ON K7L 1A6',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Kingston'],
#                            'postcode': 'K7L 1A6',
#                            'region': 'ON'},
#               'name': 'Score Pizza',
#               'popularity': 0.8481116584564861,
#               'price': 1,
#               'rating': 7.9},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#                                        'suffix': '.png'},
#                               'id': 13003,
#                               'name': 'Bar'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'distance': 258,
#               'location': {'address': '293 Princess St',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '293 Princess St, Kingston ON '
#                                                 'K7L 1B4',
#                            'locality': 'Kingston',
#                            'postcode': 'K7L 1B4',
#                            'region': 'ON'},
#               'name': 'The Alibi',
#               'popularity': 0.8166392993979201,
#               'price': 2,
#               'rating': 7.4},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#                                        'suffix': '.png'},
#                               'id': 13018,
#                               'name': 'Pub'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'distance': 333,
#               'location': {'address': '76 Princess St',
#                            'country': 'CA',
#                            'formatted_address': '76 Princess St, Kingston ON '
#                                                 'K7L 1A5',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1A5',
#                            'region': 'ON'},
#               'name': 'The Toucan',
#               'popularity': 0.9392446633825944,
#               'price': 1,
#               'rating': 8.3},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#                                        'suffix': '.png'},
#                               'id': 13099,
#                               'name': 'Chinese Restaurant'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#                                        'suffix': '.png'},
#                               'id': 13379,
#                               'name': 'Vietnamese Restaurant'}],
#               'distance': 137,
#               'location': {'address': '272 Bagot St',
#                            'country': 'CA',
#                            'cross_street': 'btwn Brock St. and Princess St.',
#                            'formatted_address': '272 Bagot St (btwn Brock St. '
#                                                 'and Princess St.), Kingston '
#                                                 'ON K7L 3G5',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 3G5',
#                            'region': 'ON'},
#               'name': 'Saigon Delights',
#               'popularity': 0.8798576902025178,
#               'price': 2,
#               'rating': 6.3},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#                                        'suffix': '.png'},
#                               'id': 13049,
#                               'name': 'Diner'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13068,
#                               'name': 'American Restaurant'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#                                        'suffix': '.png'},
#                               'id': 13314,
#                               'name': 'New American Restaurant'}],
#               'distance': 345,
#               'location': {'address': '68R Princess Ave',
#                            'address_extended': '# 4',
#                            'country': 'CA',
#                            'cross_street': 'King St',
#                            'formatted_address': '68R Princess Ave (King St), '
#                                                 'Kingston ON K7L 1A5',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1A5',
#                            'region': 'ON'},
#               'name': 'Chez Piggy',
#               'popularity': 0.9333607006020799,
#               'price': 4,
#               'rating': 8.4},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13027,
#                               'name': 'Bistro'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#                                        'suffix': '.png'},
#                               'id': 13034,
#                               'name': 'Café'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#                                        'suffix': '.png'},
#                               'id': 13145,
#                               'name': 'Fast Food Restaurant'}],
#               'distance': 261,
#               'location': {'address': '297 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'at Clergy St. E',
#                            'formatted_address': '297 Princess St (at Clergy '
#                                                 'St. E), Kingston ON K7L 1B4',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1B4',
#                            'region': 'ON'},
#               'name': 'Geneva Crepe Cafe',
#               'popularity': 0.9055829228243021,
#               'price': 1,
#               'rating': 7.4},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#                                        'suffix': '.png'},
#                               'id': 11166,
#                               'name': 'Tailor'}],
#               'distance': 70,
#               'location': {'address': '170 Princess St',
#                            'country': 'CA',
#                            'formatted_address': '170 Princess St, Kingston ON '
#                                                 'K7L 1B1',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1B1',
#                            'region': 'ON'},
#               'name': 'Andrei Master Tailors',
#               'popularity': 0.07334428024083196},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#                                        'suffix': '.png'},
#                               'id': 11045,
#                               'name': 'Bank'}],
#               'distance': 161,
#               'location': {'address': '164 Brock St',
#                            'address_extended': '# 144',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '164 Brock St, Kingston ON K7L '
#                                                 '5G2',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 5G2',
#                            'region': 'ON'},
#               'name': 'CIBC',
#               'popularity': 0.8754789272030651,
#               'rating': 6.5},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'distance': 336,
#               'location': {'address': '69 Brock St',
#                            'country': 'CA',
#                            'cross_street': 'btw King St E & Wellington',
#                            'formatted_address': '69 Brock St (btw King St E & '
#                                                 'Wellington), Kingston ON K7L '
#                                                 '1R8',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1R8',
#                            'region': 'ON'},
#               'name': 'Le Chien Noir',
#               'popularity': 0.8946360153256705,
#               'price': 1,
#               'rating': 8.1},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#                                        'suffix': '.png'},
#                               'id': 17035,
#                               'name': 'Drugstore'}],
#               'distance': 88,
#               'location': {'address': '168 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'Brock St',
#                            'formatted_address': '168 Princess St (Brock St), '
#                                                 'Kingston ON K7L 1B1',
#                            'locality': 'Kingston',
#                            'postcode': 'K7L 1B1',
#                            'region': 'ON'},
#               'name': "Graham's Pharmacy",
#               'popularity': 0.7493158182813355},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#                                        'suffix': '.png'},
#                               'id': 13276,
#                               'name': 'Sushi Restaurant'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#                                        'suffix': '.png'},
#                               'id': 13338,
#                               'name': 'Seafood Restaurant'}],
#               'distance': 362,
#               'location': {'address': '66 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'at King St E.',
#                            'formatted_address': '66 Princess St (at King St '
#                                                 'E.), Kingston ON K7L 1A5',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1A5',
#                            'region': 'ON'},
#               'name': 'Sima Sushi',
#               'popularity': 0.900519978106185,
#               'price': 2,
#               'rating': 8.1},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#                                        'suffix': '.png'},
#                               'id': 13025,
#                               'name': 'Wine Bar'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#                                        'suffix': '.png'},
#                               'id': 13347,
#                               'name': 'Tapas Restaurant'}],
#               'distance': 407,
#               'location': {'address': '331 King St E',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '331 King St E, Kingston ON '
#                                                 'K7L 3B5',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Kingston'],
#                            'postcode': 'K7L 3B5',
#                            'region': 'ON'},
#               'name': 'Tango Nuevo',
#               'popularity': 0.9270662287903667,
#               'price': 3,
#               'rating': 8.9},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#                                        'suffix': '.png'},
#                               'id': 13018,
#                               'name': 'Pub'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'distance': 276,
#               'location': {'address': '207 Wellington St',
#                            'country': 'CA',
#                            'cross_street': 'Queen',
#                            'formatted_address': '207 Wellington St (Queen), '
#                                                 'Kingston ON K7K 2Y6',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7K 2Y6',
#                            'region': 'ON'},
#               'name': 'The Iron Duke on Wellington',
#               'popularity': 0.8981937602627258,
#               'price': 1,
#               'rating': 7.1},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#                                        'suffix': '.png'},
#                               'id': 12101,
#                               'name': 'Church'}],
#               'distance': 109,
#               'location': {'address': '137 Queen St',
#                            'country': 'CA',
#                            'formatted_address': '137 Queen St, Kingston ON K7K '
#                                                 '1A8',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7K 1A8',
#                            'region': 'ON'},
#               'name': "St Paul's Anglican Church",
#               'popularity': 0.9363711001642037},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#                                        'suffix': '.png'},
#                               'id': 13018,
#                               'name': 'Pub'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'distance': 396,
#               'location': {'address': '343 King St E',
#                            'country': 'CA',
#                            'formatted_address': '343 King St E, Kingston ON '
#                                                 'K7L 3B5',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Kingston'],
#                            'postcode': 'K7L 3B5',
#                            'region': 'ON'},
#               'name': "Sir John's Public House",
#               'popularity': 0.8486590038314177,
#               'price': 1,
#               'rating': 8.4},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#                                        'suffix': '.png'},
#                               'id': 13002,
#                               'name': 'Bakery'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#                                        'suffix': '.png'},
#                               'id': 13049,
#                               'name': 'Diner'}],
#               'distance': 423,
#               'location': {'address': '44 Princess St',
#                            'country': 'CA',
#                            'formatted_address': '44 Princess St, Kingston ON '
#                                                 'K7L 1A4',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1A4',
#                            'region': 'ON'},
#               'name': 'Pan Chancho Bakery',
#               'popularity': 0.9662014230979749,
#               'price': 2,
#               'rating': 9.1},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#                                        'suffix': '.png'},
#                               'id': 10035,
#                               'name': 'Performing Arts Venue'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#                                        'suffix': '.png'},
#                               'id': 13034,
#                               'name': 'Café'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'distance': 328,
#               'location': {'address': '73 Brock St',
#                            'country': 'CA',
#                            'formatted_address': '73 Brock St, Kingston ON K7L '
#                                                 '1R8',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Kingston'],
#                            'postcode': 'K7L 1R8',
#                            'region': 'ON'},
#               'name': 'Musiikki',
#               'popularity': 0.8467432950191571,
#               'rating': 7.5},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#                                        'suffix': '.png'},
#                               'id': 17052,
#                               'name': "Women's Store"}],
#               'distance': 115,
#               'location': {'address': '169 Princess St',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '169 Princess St, Kingston ON '
#                                                 'K7L 1A9',
#                            'locality': 'Kingston',
#                            'postcode': 'K7L 1A9',
#                            'region': 'ON'},
#               'name': 'Overstock',
#               'popularity': 0.17364532019704434},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#                                        'suffix': '.png'},
#                               'id': 19014,
#                               'name': 'Hotel'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#                                        'suffix': '.png'},
#                               'id': 19015,
#                               'name': 'Inn'}],
#               'distance': 202,
#               'location': {'address': '125 Brock St',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '125 Brock St, Kingston ON K7L '
#                                                 '1S1',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1S1',
#                            'region': 'ON'},
#               'name': "The Queen's Inn",
#               'popularity': 0.837712096332786,
#               'price': 1,
#               'rating': 6.4},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#                                        'suffix': '.png'},
#                               'id': 13049,
#                               'name': 'Diner'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13096,
#                               'name': 'Cambodian Restaurant'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#                                        'suffix': '.png'},
#                               'id': 13352,
#                               'name': 'Thai Restaurant'}],
#               'distance': 119,
#               'location': {'address': '161 Brock St',
#                            'country': 'CA',
#                            'cross_street': 'Brock and Montreal',
#                            'formatted_address': '161 Brock St (Brock and '
#                                                 'Montreal), Kingston ON K7L '
#                                                 '1S2',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1S2',
#                            'region': 'ON'},
#               'name': 'Cambodiana Restaurant',
#               'popularity': 0.5192939244663383,
#               'price': 2},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#                                        'suffix': '.png'},
#                               'id': 17018,
#                               'name': 'Bookstore'}],
#               'distance': 121,
#               'location': {'address': '156 Princess St',
#                            'country': 'CA',
#                            'cross_street': 'Princess & Bagot',
#                            'formatted_address': '156 Princess St (Princess & '
#                                                 'Bagot), Kingston ON K7L 1B1',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1B1',
#                            'region': 'ON'},
#               'name': 'Novel Idea',
#               'popularity': 0.8258073344280241},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13032,
#                               'name': 'Cafes, Coffee, and Tea Houses'}],
#               'distance': 360,
#               'location': {'address': '61 Brock St',
#                            'country': 'CA',
#                            'cross_street': 'btwn King & Wellington St.',
#                            'formatted_address': '61 Brock St (btwn King & '
#                                                 'Wellington St.), Kingston ON '
#                                                 'K7L 1R8',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7L 1R8',
#                            'region': 'ON'},
#               'name': "Cooke's Fine Foods and Coffee",
#               'popularity': 0.8793103448275862,
#               'rating': 7.7},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#                                        'suffix': '.png'},
#                               'id': 11027,
#                               'name': 'Computer Repair Service'}],
#               'distance': 125,
#               'location': {'address': '303 Bagot St',
#                            'address_extended': 'Suite 16A',
#                            'country': 'CA',
#                            'cross_street': 'BTW Princess Street',
#                            'formatted_address': '303 Bagot St (BTW Princess '
#                                                 'Street), Kingston ON K7K 5W7',
#                            'locality': 'Kingston',
#                            'neighborhood': ['Sydenham'],
#                            'postcode': 'K7K 5W7',
#                            'region': 'ON'},
#               'name': 'Kingston Online Svc',
#               'popularity': 0.4393814997263273}]}

# %% [markdown]
# From the response above, we can see that we have a nested dictionary. The details we want to keep are within the results key, which on the other hand is a list of dictionaries with each POI. Within each entry, we may want to keep the category name, POI name and location (formatted address). Let's explore this structure below.

# %%
# number of POIs
len(fsq_data['results'])

# POI Name
#poi_name = fsq_data['results'][0]['name']
#poi_name

# POI address
#poi_address = fsq_data['results'][0]['location']['address']
#poi_address

# POI type
#poi_type = fsq_data['results'][0]['categories'][0]['name']
#poi_type

# POI rating
#poi_rating = fsq_data['results'][0]['rating']
#poi_rating

# POI price
#poi_price = fsq_data['results'][4]['price']
#poi_price

# POI popularity
#poi_popularity = fsq_data['results'][4]['popularity']
#poi_popularity
# Out:
# 50

# %%
# Not all entries have ratings or prices, so we need to add an exception to handle that
# The example below shows how some ratings are missing.

rating_key = 'rating'
price_key = 'price' # will be used later

for i in range(len(fsq_data['results'])):
    if rating_key in fsq_data['results'][i]:
        print('Rating is available')
        
    else:
        print('Rating is unavailable')
# Out:
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is unavailable
# Rating is unavailable
# Rating is available
# Rating is available
# Rating is unavailable
# Rating is available
# Rating is unavailable
# Rating is unavailable
# Rating is available
# Rating is unavailable
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is available
# Rating is unavailable
# Rating is available
# Rating is available
# Rating is unavailable
# Rating is available
# Rating is available
# Rating is available
# Rating is unavailable
# Rating is available
# Rating is available
# Rating is available
# Rating is unavailable
# Rating is available
# Rating is unavailable
# Rating is unavailable
# Rating is available
# Rating is unavailable

# %% [markdown]
# Loop through the entries to create a dict which we will import to pandas dataframe

# %%
# Empty lists that we will add to the dict
names = []
addresses = []
types = []
ratings = []
prices = []
popularity = []

# %%
for i in range(len(fsq_data['results'])):
    # add POI name to names list
    names.append(fsq_data['results'][i]['name'])
    
    # add POI address to addresses list
    addresses.append(fsq_data['results'][i]['location']['address'])
    
    # add POI type to types list
    types.append(fsq_data['results'][i]['categories'][0]['name'])
    
    # add POI rating to ratings list - need to account for missing ratings
    if rating_key in fsq_data['results'][i]:
        ratings.append(fsq_data['results'][i]['rating'])
    else:
        ratings.append('NA')
        
    # add POI price info to prices list - also use the if statement to handle missing values
    if price_key in fsq_data['results'][i]:
        prices.append(fsq_data['results'][i]['price'])
    else:
        prices.append('NA')

    # add POI popularity rating to popularity list
    popularity.append(fsq_data['results'][i]['popularity'])

# Print lists to check 
#print(names)
#print(addresses)
#print(types)
#print(ratings)
#print(prices)
#print(popularity)
# Out:
# ['Minotaur Games & Gifts', 'Dollarama', 'Crave Coffee House & Bakery', "Menchie's", 'Stone City Ales', 'Amadeus Cafe', 'Hwa-Ki', 'The Screening Room', "Balzac's Coffee", 'Grecos Grill & Wine Bar', 'Lululemon Athletica', 'Shoppers Drug Mart', 'Urban Outfitters', 'NORTHSIDE espresso + kitchen', "Harper's", 'Golden Rooster Delicatessen', 'Copper Penny', 'Kingston Frameworks', 'Plaza Hotel', 'Ta Ke Sushi', 'Starbucks', 'Racquet Science', "Megalo's Restaurants", 'Union Kitchen + Cocktails', 'Northern Chinese Barbeque', 'Mango Thai & Pan-Asian Cuisine', 'True North Tattoo', 'Score Pizza', 'The Alibi', 'The Toucan', 'Saigon Delights', 'Chez Piggy', 'Geneva Crepe Cafe', 'Andrei Master Tailors', 'CIBC', 'Le Chien Noir', "Graham's Pharmacy", 'Sima Sushi', 'Tango Nuevo', 'The Iron Duke on Wellington', "St Paul's Anglican Church", "Sir John's Public House", 'Pan Chancho Bakery', 'Musiikki', 'Overstock', "The Queen's Inn", 'Cambodiana Restaurant', 'Novel Idea', "Cooke's Fine Foods and Coffee", 'Kingston Online Svc']
# ['165 Princess St', '176 Princess St', '166 Princess St', '241 Princess St', '275 Princess St', '170 Princess St', '269 Princess St', '120 Princess St', '251 Princess St', '167 Princess St', '270 Princess St', '136 Princess St', '207 Princess St', '281 Princess St', '93 Princess St', '111 Princess St', '240 Princess St', '198 Princess St', '46 Montreal St', '120 Princess St', '95 Princess St', '332A Barrie St', '226 Princess St', '184 Princess St', '185 Princess St', '161 Princess St', '159 Queen St', '91 Princess St', '293 Princess St', '76 Princess St', '272 Bagot St', '68R Princess Ave', '297 Princess St', '170 Princess St', '164 Brock St', '69 Brock St', '168 Princess St', '66 Princess St', '331 King St E', '207 Wellington St', '137 Queen St', '343 King St E', '44 Princess St', '73 Brock St', '169 Princess St', '125 Brock St', '161 Brock St', '156 Princess St', '61 Brock St', '303 Bagot St']
# ['Gift Store', 'Discount Store', 'Bakery', 'Frozen Yogurt Shop', 'Brewery', 'Café', 'Sushi Restaurant', 'Indie Movie Theater', 'Café', 'Diner', 'Sporting Goods Retail', 'Drugstore', 'Clothing Store', 'Dining and Drinking', 'Restaurant', 'Caterer', 'American Restaurant', 'Art Gallery', 'Hotel', 'Sushi Restaurant', 'Coffee Shop', 'Bicycle Store', 'New American Restaurant', 'Night Club', 'Chinese Restaurant', 'American Restaurant', 'Tattoo Parlor', 'Pizzeria', 'Bar', 'Pub', 'Chinese Restaurant', 'Diner', 'Bistro', 'Tailor', 'Bank', 'Restaurant', 'Drugstore', 'Sushi Restaurant', 'Wine Bar', 'Pub', 'Church', 'Pub', 'Bakery', 'Performing Arts Venue', "Women's Store", 'Hotel', 'Diner', 'Bookstore', 'Cafes, Coffee, and Tea Houses', 'Computer Repair Service']
# [8.4, 7.3, 8.0, 7.7, 9.0, 6.9, 7.9, 8.3, 7.3, 6.6, 7.6, 7.2, 5.8, 7.6, 8.3, 7.5, 6.5, 'NA', 'NA', 7.3, 7.9, 'NA', 5.9, 'NA', 'NA', 6.0, 'NA', 7.9, 7.4, 8.3, 6.3, 8.4, 7.4, 'NA', 6.5, 8.1, 'NA', 8.1, 8.9, 7.1, 'NA', 8.4, 9.1, 7.5, 'NA', 6.4, 'NA', 'NA', 7.7, 'NA']
# ['NA', 'NA', 1, 1, 2, 2, 2, 'NA', 1, 2, 'NA', 'NA', 'NA', 1, 2, 1, 2, 'NA', 3, 3, 1, 'NA', 2, 3, 1, 2, 'NA', 1, 2, 1, 2, 4, 1, 'NA', 'NA', 1, 'NA', 2, 3, 1, 'NA', 1, 2, 'NA', 'NA', 1, 2, 'NA', 'NA', 'NA']
# [0.8620689655172413, 0.934592227695676, 0.9579912424740011, 0.8155446086480569, 0.9329501915708812, 0.9239189928845101, 0.29064039408866993, 0.8735632183908046, 0.9407498631636563, 0.9131089217296113, 0.9314449917898193, 0.972495894909688, 0.9088669950738916, 0.8457854406130269, 0.8856048166392994, 0.942391899288451, 0.9038040503557745, 0.8357963875205254, 0.7837985769020251, 0.22099069512862615, 0.9429392446633826, 0.180623973727422, 0.9066776135741653, 0.925424192665572, 0.8854679802955665, 0.8700054734537493, 0.8648056923918993, 0.8481116584564861, 0.8166392993979201, 0.9392446633825944, 0.8798576902025178, 0.9333607006020799, 0.9055829228243021, 0.07334428024083196, 0.8754789272030651, 0.8946360153256705, 0.7493158182813355, 0.900519978106185, 0.9270662287903667, 0.8981937602627258, 0.9363711001642037, 0.8486590038314177, 0.9662014230979749, 0.8467432950191571, 0.17364532019704434, 0.837712096332786, 0.5192939244663383, 0.8258073344280241, 0.8793103448275862, 0.4393814997263273]

# %%
# Create a dict with the lists
fsq_dict = {
    'Name': names,
    'Address': addresses,
    'Type': types,
    'Rating': ratings,
    'Price': prices,
    'Popularity': popularity
}

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# create a dataframe from the fsq_dict variable, rounding to two decimals for readability
fsq_df = pd.DataFrame(fsq_dict).round(2)
fsq_df
# Out:
#                               Name            Address  \
# 0           Minotaur Games & Gifts    165 Princess St
# 1                        Dollarama    176 Princess St
# 2      Crave Coffee House & Bakery    166 Princess St
# 3                        Menchie's    241 Princess St
# 4                  Stone City Ales    275 Princess St
# 5                     Amadeus Cafe    170 Princess St
# 6                           Hwa-Ki    269 Princess St
# 7               The Screening Room    120 Princess St
# 8                  Balzac's Coffee    251 Princess St
# 9          Grecos Grill & Wine Bar    167 Princess St
# 10             Lululemon Athletica    270 Princess St
# 11              Shoppers Drug Mart    136 Princess St
# 12                Urban Outfitters    207 Princess St
# 13    NORTHSIDE espresso + kitchen    281 Princess St
# 14                        Harper's     93 Princess St
# 15     Golden Rooster Delicatessen    111 Princess St
# 16                    Copper Penny    240 Princess St
# 17             Kingston Frameworks    198 Princess St
# 18                     Plaza Hotel     46 Montreal St
# 19                     Ta Ke Sushi    120 Princess St
# 20                       Starbucks     95 Princess St
# 21                 Racquet Science     332A Barrie St
# 22            Megalo's Restaurants    226 Princess St
# 23       Union Kitchen + Cocktails    184 Princess St
# 24       Northern Chinese Barbeque    185 Princess St
# 25  Mango Thai & Pan-Asian Cuisine    161 Princess St
# 26               True North Tattoo       159 Queen St
# 27                     Score Pizza     91 Princess St
# 28                       The Alibi    293 Princess St
# 29                      The Toucan     76 Princess St
# 30                 Saigon Delights       272 Bagot St
# 31                      Chez Piggy   68R Princess Ave
# 32               Geneva Crepe Cafe    297 Princess St
# 33           Andrei Master Tailors    170 Princess St
# 34                            CIBC       164 Brock St
# 35                   Le Chien Noir        69 Brock St
# 36               Graham's Pharmacy    168 Princess St
# 37                      Sima Sushi     66 Princess St
# 38                     Tango Nuevo      331 King St E
# 39     The Iron Duke on Wellington  207 Wellington St
# 40       St Paul's Anglican Church       137 Queen St
# 41         Sir John's Public House      343 King St E
# 42              Pan Chancho Bakery     44 Princess St
# 43                        Musiikki        73 Brock St
# 44                       Overstock    169 Princess St
# 45                 The Queen's Inn       125 Brock St
# 46           Cambodiana Restaurant       161 Brock St
# 47                      Novel Idea    156 Princess St
# 48   Cooke's Fine Foods and Coffee        61 Brock St
# 49             Kingston Online Svc       303 Bagot St
#
#                              Type Rating Price  Popularity
# 0                      Gift Store    8.4    NA        0.86
# 1                  Discount Store    7.3    NA        0.93
# 2                          Bakery    8.0     1        0.96
# 3              Frozen Yogurt Shop    7.7     1        0.82
# 4                         Brewery    9.0     2        0.93
# 5                            Café    6.9     2        0.92
# 6                Sushi Restaurant    7.9     2        0.29
# 7             Indie Movie Theater    8.3    NA        0.87
# 8                            Café    7.3     1        0.94
# 9                           Diner    6.6     2        0.91
# 10          Sporting Goods Retail    7.6    NA        0.93
# 11                      Drugstore    7.2    NA        0.97
# 12                 Clothing Store    5.8    NA        0.91
# 13            Dining and Drinking    7.6     1        0.85
# 14                     Restaurant    8.3     2        0.89
# 15                        Caterer    7.5     1        0.94
# 16            American Restaurant    6.5     2        0.90
# 17                    Art Gallery     NA    NA        0.84
# 18                          Hotel     NA     3        0.78
# 19               Sushi Restaurant    7.3     3        0.22
# 20                    Coffee Shop    7.9     1        0.94
# 21                  Bicycle Store     NA    NA        0.18
# 22        New American Restaurant    5.9     2        0.91
# 23                     Night Club     NA     3        0.93
# 24             Chinese Restaurant     NA     1        0.89
# 25            American Restaurant    6.0     2        0.87
# 26                  Tattoo Parlor     NA    NA        0.86
# 27                       Pizzeria    7.9     1        0.85
# 28                            Bar    7.4     2        0.82
# 29                            Pub    8.3     1        0.94
# 30             Chinese Restaurant    6.3     2        0.88
# 31                          Diner    8.4     4        0.93
# 32                         Bistro    7.4     1        0.91
# 33                         Tailor     NA    NA        0.07
# 34                           Bank    6.5    NA        0.88
# 35                     Restaurant    8.1     1        0.89
# 36                      Drugstore     NA    NA        0.75
# 37               Sushi Restaurant    8.1     2        0.90
# 38                       Wine Bar    8.9     3        0.93
# 39                            Pub    7.1     1        0.90
# 40                         Church     NA    NA        0.94
# 41                            Pub    8.4     1        0.85
# 42                         Bakery    9.1     2        0.97
# 43          Performing Arts Venue    7.5    NA        0.85
# 44                  Women's Store     NA    NA        0.17
# 45                          Hotel    6.4     1        0.84
# 46                          Diner     NA     2        0.52
# 47                      Bookstore     NA    NA        0.83
# 48  Cafes, Coffee, and Tea Houses    7.7    NA        0.88
# 49        Computer Repair Service     NA    NA        0.44

# %%
# Explore the data by sorting based on popularity
pop = fsq_df[['Name', 'Type', 'Popularity']].nlargest(5, 'Popularity', keep='all')
pop
# Out:
#                            Name         Type  Popularity
# 11           Shoppers Drug Mart    Drugstore        0.97
# 42           Pan Chancho Bakery       Bakery        0.97
# 2   Crave Coffee House & Bakery       Bakery        0.96
# 8               Balzac's Coffee         Café        0.94
# 15  Golden Rooster Delicatessen      Caterer        0.94
# 20                    Starbucks  Coffee Shop        0.94
# 29                   The Toucan          Pub        0.94
# 40    St Paul's Anglican Church       Church        0.94

# %%
# Let's look at some statistics for popularity
# This rating goes from 0 to 1, with one being most popular
print(fsq_df['Popularity'].max())
print(fsq_df['Popularity'].min())
print(fsq_df['Popularity'].mean())
# Out:
# 0.97
# 0.07
# 0.8036000000000001

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request with the same location paramaters (location, radius, etc)

# %%
# Set the key
yelp_api_key = os.environ['YELP_API_KEY']

# %%
# Set the GET url according to Yelp API documentation 
# First, define host p
host = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer {}'.format(yelp_api_key)}

# This is the latitude, should be a decimal 
lat = 44.232344187881836

# This is the longitude, should be a decimal 
lon = -76.48559630147832

# Radius should be an int
radius = 1000 

# Limit should be an int
limit = 50

# Parameters for our request
params = f'?latitude={lat}&longitude={lon}&radius={radius}&limit={limit}'


# For comparison's sake I didn't specify the type of venue I am looking for
# Combine  
url = host+params
print(url)
# Out:
# https://api.yelp.com/v3/businesses/search?latitude=44.232344187881836&longitude=-76.48559630147832&radius=1000&limit=50

# %%
# get request
yelp_response = requests.get(url, headers=headers)

# %%
yelp_response.status_code
# Out:
# 200

# %%
# save the response as a json file to prevent from sending repeated requests

# !!! DON'T RUN OR IT WILL OVERWRITE THE SAVED FILE !!!

#with open('yelp_response.json', 'w') as f:
#    f.write(yelp_response.text)

# %% [markdown]
# Parse through your result and get POI details

# %%
with open('yelp_response.json') as f:
    yelp_data = json.load(f)
pprint.pprint(yelp_data)
# Out:
# {'businesses': [{'alias': 'wooden-heads-kingston',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'mediterranean',
#                                  'title': 'Mediterranean'},
#                                 {'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 44.2290169,
#                                  'longitude': -76.48106688543417},
#                  'display_phone': '+1 613-549-1812',
#                  'distance': 516.8355833542643,
#                  'id': 'sZ3glyC2gtZL0Hk08RFkWQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cT37Xk72f91rQzVLW_nsCw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '192 Ontario Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['192 Ontario Street',
#                                                   'Kingston, ON K7L 2Y8',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 2Y8'},
#                  'name': 'Wooden Heads',
#                  'phone': '+16135491812',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 197,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/wooden-heads-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'tango-nuevo-kingston',
#                  'categories': [{'alias': 'tapasmallplates',
#                                  'title': 'Tapas/Small Plates'},
#                                 {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#                  'coordinates': {'latitude': 44.2305918,
#                                  'longitude': -76.4810459},
#                  'display_phone': '+1 613-548-3778',
#                  'distance': 411.5957464595122,
#                  'id': 'RsjNzXjwHpO-4QjY-vHEew',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XQJ3NFpOn1nhrlelh1IJyQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '331 King Street E',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['331 King Street E',
#                                                   'Kingston, ON K7L 3B5',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 3B5'},
#                  'name': 'Tango Nuevo',
#                  'phone': '+16135483778',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 102,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/tango-nuevo-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'pan-chancho-bakery-kingston',
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'desserts', 'title': 'Desserts'},
#                                 {'alias': 'cafes', 'title': 'Cafes'}],
#                  'coordinates': {'latitude': 44.23111, 'longitude': -76.48047},
#                  'display_phone': '+1 613-544-7790',
#                  'distance': 427.6585380927615,
#                  'id': 'C1CWKXL995RTB5MwskaOSQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RinCRj2qA2zMNtKQQn_R_g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '44 Princess Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['44 Princess Street',
#                                                   'Kingston, ON K7L 1A4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1A4'},
#                  'name': 'Pan Chancho Bakery',
#                  'phone': '+16135447790',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 141,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/pan-chancho-bakery-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'harpers-kingston',
#                  'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 44.231632576766636,
#                                  'longitude': -76.48219077869685},
#                  'display_phone': '+1 613-507-3663',
#                  'distance': 282.6322191722046,
#                  'id': 'tggyQw_cs1s99u1aGg09TA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MAHBQV999Vt2phlEdvVNgg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '93 Princess Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['93 Princess Street',
#                                                   'Kingston, ON K7L 1A6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1A6'},
#                  'name': "Harper's",
#                  'phone': '+16135073663',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 123,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/harpers-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'grecos-grill-and-wine-bar-kingston-2',
#                  'categories': [{'alias': 'greek', 'title': 'Greek'}],
#                  'coordinates': {'latitude': 44.23201327298664,
#                                  'longitude': -76.4846335},
#                  'display_phone': '+1 613-542-2229',
#                  'distance': 85.07812847284075,
#                  'id': '9kyRlNiDqk6m0at5kluGqQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BlAPMr2aSz6yzSXhe58aZA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '167 Princess Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['167 Princess Street',
#                                                   'Kingston, ON K7L 1A9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1A9'},
#                  'name': "Greco's Grill and Wine Bar",
#                  'phone': '+16135422229',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 79,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/grecos-grill-and-wine-bar-kingston-2?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'wok-in-restaurant-kingston',
#                  'categories': [{'alias': 'cambodian', 'title': 'Cambodian'},
#                                 {'alias': 'thai', 'title': 'Thai'},
#                                 {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#                  'coordinates': {'latitude': 44.23234, 'longitude': -76.48564},
#                  'display_phone': '+1 613-549-5369',
#                  'distance': 6.2929339470710985,
#                  'id': 'YCaq7v7IJhbtRbNnN1CLvw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3M4hlYEW7PaTnKk9eHGR4Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '30 Montreal St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['30 Montreal St',
#                                                   'Kingston, ON K7K 3E6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7K 3E6'},
#                  'name': 'Wok-In Restaurant',
#                  'phone': '+16135495369',
#                  'price': '$',
#                  'rating': 5.0,
#                  'review_count': 36,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/wok-in-restaurant-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'sima-sushi-kingston',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 44.23125, 'longitude': -76.48136},
#                  'display_phone': '+1 613-542-8040',
#                  'distance': 361.2153679516416,
#                  'id': 'O0nX6fu7dzKQtP9owhVkzQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c8pbwnpN75s_PMjEIltXGw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '66 Princess St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['66 Princess St',
#                                                   'Kingston, ON K7L 1A5',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1A5'},
#                  'name': 'Sima Sushi',
#                  'phone': '+16135428040',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 96,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sima-sushi-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'northside-espresso-kitchen-kingston',
#                  'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#                  'coordinates': {'latitude': 44.23269, 'longitude': -76.4883},
#                  'display_phone': '',
#                  'distance': 221.78052565341682,
#                  'id': '7cXz0Z9DMq866JmembgS3w',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gotStCHEAXjcUAql3WiOcQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '281 Princess Street',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['281 Princess Street',
#                                                   'Kingston, ON K7L 1B5',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1B5'},
#                  'name': 'NORTHSIDE Espresso + Kitchen',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 51,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/northside-espresso-kitchen-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'mio-gelato-kingston-2',
#                  'categories': [{'alias': 'icecream',
#                                  'title': 'Ice Cream & Frozen Yogurt'}],
#                  'coordinates': {'latitude': 44.2289635820445,
#                                  'longitude': -76.4811571040206},
#                  'display_phone': '+1 613-547-4053',
#                  'distance': 516.1440967706318,
#                  'id': 'iJz1rJcZU3ws2bF5PbpVWw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zgvEZGKVUdqEQAUo5CC4Uw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '178 Ontario Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['178 Ontario Street',
#                                                   'Kingston, ON K7L 2Y8',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 2Y8'},
#                  'name': 'Mio Gelato',
#                  'phone': '+16135474053',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 52,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mio-gelato-kingston-2?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'amadeus-cafe-kingston',
#                  'categories': [{'alias': 'german', 'title': 'German'},
#                                 {'alias': 'austrian', 'title': 'Austrian'}],
#                  'coordinates': {'latitude': 44.2318, 'longitude': -76.48492},
#                  'display_phone': '+1 613-546-7468',
#                  'distance': 86.23629389435928,
#                  'id': '6WleKk69TZ_MSaVPf966Ag',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/pZTVH4yecRMW33nI6DUw5A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '170 Princess Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['170 Princess Street',
#                                                   'Kingston, ON K7L 1B1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1B1'},
#                  'name': 'Amadeus Cafe',
#                  'phone': '+16135467468',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 34,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/amadeus-cafe-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'diannes-fish-shack-and-smokehouse-kingston',
#                  'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'smokehouse', 'title': 'Smokehouse'},
#                                 {'alias': 'fishnchips',
#                                  'title': 'Fish & Chips'}],
#                  'coordinates': {'latitude': 44.2291141,
#                                  'longitude': -76.4808009},
#                  'display_phone': '+1 613-507-3474',
#                  'distance': 524.3883499835013,
#                  'id': 'iqG1xY2fvm_Qyvet51HGKw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EH3jWq8tm5qIdvMUAcvaLQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '195 Ontario Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['195 Ontario Street',
#                                                   'Kingston, ON K7L 2Y7',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 2Y7'},
#                  'name': "Dianne's Fish Shack & Smokehouse",
#                  'phone': '+16135073474',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 144,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/diannes-fish-shack-and-smokehouse-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'chez-piggy-restaurant-kingston',
#                  'categories': [{'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'}],
#                  'coordinates': {'latitude': 44.23125,
#                                  'longitude': -76.4813999},
#                  'display_phone': '+1 613-549-7673',
#                  'distance': 354.4144893597508,
#                  'id': 'dleML3mi8ywo5iV6ZcQOcQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zEuaNYQPbXXlssvgdvknWw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '68R Princess Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['68R Princess Street',
#                                                   'Kingston, ON K7L 1A5',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1A5'},
#                  'name': 'Chez Piggy Restaurant',
#                  'phone': '+16135497673',
#                  'price': '$$$',
#                  'rating': 3.5,
#                  'review_count': 104,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/chez-piggy-restaurant-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'sallys-roti-shop-kingston',
#                  'categories': [{'alias': 'caribbean', 'title': 'Caribbean'}],
#                  'coordinates': {'latitude': 44.23191, 'longitude': -76.48202},
#                  'display_phone': '+1 613-766-6293',
#                  'distance': 275.696605850773,
#                  'id': 'RXhemp7IwuCKGoiMAVBlRQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LtyGzyXUobGkHH_0zTDYug/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '203 Wellington Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['203 Wellington Street',
#                                                   'Kingston, ON K7K 6W7',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7K 6W7'},
#                  'name': "Sally's Roti Shop",
#                  'phone': '+16137666293',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 35,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sallys-roti-shop-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'red-house-kingston',
#                  'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#                  'coordinates': {'latitude': 44.2316399,
#                                  'longitude': -76.4806213},
#                  'display_phone': '+1 613-767-2558',
#                  'distance': 384.29435922485453,
#                  'id': 'vSWT_tGmreZP3cP2exvW_w',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ir9avHJmTt2iay4Nn6mcvw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '369 King Street E',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['369 King Street E',
#                                                   'Kingston, ON K7K 2Y1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7K 2Y1'},
#                  'name': 'Red House',
#                  'phone': '+16137672558',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 63,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/red-house-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'black-dog-tavern-kingston-2',
#                  'categories': [{'alias': 'french', 'title': 'French'},
#                                 {'alias': 'gastropubs', 'title': 'Gastropubs'},
#                                 {'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'}],
#                  'coordinates': {'latitude': 44.23071, 'longitude': -76.48196},
#                  'display_phone': '+1 613-549-5635',
#                  'distance': 333.71752876376866,
#                  'id': 'WCSsJDWv68NZHRfXRPezbQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SfTAO_vofMbS0QfGifM8CA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '69 Brock Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['69 Brock Street',
#                                                   'Kingston, ON K7L 1R8',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1R8'},
#                  'name': 'Black Dog Tavern',
#                  'phone': '+16135495635',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 79,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/black-dog-tavern-kingston-2?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'olivea-kingston',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 44.23054, 'longitude': -76.48088},
#                  'display_phone': '+1 613-547-5483',
#                  'distance': 425.36205027035294,
#                  'id': '3hpB3OsG1nsg6gYSTiRSSQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/H-oGxzcflZQ1j8rCY3vRKQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '39 Brock Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['39 Brock Street',
#                                                   'Kingston, ON K7L 1R7',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1R7'},
#                  'name': 'Olivea',
#                  'phone': '+16135475483',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 75,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/olivea-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'balzacs-coffee-roasters-kingston-2',
#                  'categories': [{'alias': 'coffeeroasteries',
#                                  'title': 'Coffee Roasteries'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 44.2324232141175,
#                                  'longitude': -76.4874007110315},
#                  'display_phone': '+1 613-417-0600',
#                  'distance': 144.0308592219333,
#                  'id': 'nGvEIGa7BOiv6yDA9K4ujA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qDDfM8JuwG_UATWhPQqNpg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '251 Princess Street',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['251 Princess Street',
#                                                   'Kingston, ON K7L 1B4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1B4'},
#                  'name': "Balzac's Coffee Roasters",
#                  'phone': '+16134170600',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 13,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/balzacs-coffee-roasters-kingston-2?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'score-pizza-kingston',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'salad', 'title': 'Salad'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 44.23167, 'longitude': -76.48211},
#                  'display_phone': '+1 613-542-1200',
#                  'distance': 289.2267851324706,
#                  'id': 'n09TrJu8416dtpe9lRk3ig',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qzsSeZbI91-cdD7whJqXlQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '91 Princess Street',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['91 Princess Street',
#                                                   'Kingston, ON K7L 1A6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1A6'},
#                  'name': 'Score Pizza',
#                  'phone': '+16135421200',
#                  'rating': 4.5,
#                  'review_count': 32,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/score-pizza-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'ali-baba-kingston',
#                  'categories': [{'alias': 'persian',
#                                  'title': 'Persian/Iranian'},
#                                 {'alias': 'mideastern',
#                                  'title': 'Middle Eastern'}],
#                  'coordinates': {'latitude': 44.2325325,
#                                  'longitude': -76.489624},
#                  'display_phone': '+1 613-531-9999',
#                  'distance': 309.24056767283435,
#                  'id': 'VlobLVKVZkVnqTXvn5fNPA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rvW37cb3SfFZRA3f70n7Sw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '320 Princess St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['320 Princess St',
#                                                   'Kingston, ON K7L 1B6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1B6'},
#                  'name': 'Ali Baba',
#                  'phone': '+16135319999',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 30,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ali-baba-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'kame-sushi-and-izakaya-kingston',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#                  'coordinates': {'latitude': 44.2326698,
#                                  'longitude': -76.4930191},
#                  'display_phone': '+1 613-546-6399',
#                  'distance': 588.2858893794321,
#                  'id': 'AzTvASeUNN1-07AByUJccQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/aoehm5n07SDt0YTjh3Gd6g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '156 Division St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['156 Division St',
#                                                   'Kingston, ON K7L',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L'},
#                  'name': 'Kame Sushi and Izakaya',
#                  'phone': '+16135466399',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 35,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kame-sushi-and-izakaya-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'the-cambodian-village-kingston',
#                  'categories': [{'alias': 'cambodian', 'title': 'Cambodian'},
#                                 {'alias': 'thai', 'title': 'Thai'}],
#                  'coordinates': {'latitude': 44.23099, 'longitude': -76.48084},
#                  'display_phone': '+1 613-536-0426',
#                  'distance': 401.82080511724814,
#                  'id': '_4DPfuQTllKZcegjlQfpAg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/n65C6bIK84z_IgLQmrOtkQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '347 King Street E',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['347 King Street E',
#                                                   'Kingston, ON K7L 3B5',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 3B5'},
#                  'name': 'The Cambodian Village',
#                  'phone': '+16135360426',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 23,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-cambodian-village-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'geneva-crepe-cafe-kingston',
#                  'categories': [{'alias': 'creperies', 'title': 'Creperies'},
#                                 {'alias': 'desserts', 'title': 'Desserts'},
#                                 {'alias': 'cafes', 'title': 'Cafes'}],
#                  'coordinates': {'latitude': 44.2324657,
#                                  'longitude': -76.4881824},
#                  'display_phone': '+1 613-507-0297',
#                  'distance': 206.48445447172585,
#                  'id': 'S4z-xLmyI2dGmGmsGYL0jg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YOZojDqJG68ME8_TA7NKIw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '297 Princess Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['297 Princess Street',
#                                                   'Kingston, ON K7L 3J4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 3J4'},
#                  'name': 'Geneva Crepe Cafe',
#                  'phone': '+16135070297',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 50,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/geneva-crepe-cafe-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'gangnam-style-kingston',
#                  'categories': [{'alias': 'korean', 'title': 'Korean'}],
#                  'coordinates': {'latitude': 44.23286, 'longitude': -76.48988},
#                  'display_phone': '+1 613-531-6087',
#                  'distance': 349.78269463602476,
#                  'id': 'RT1HlvUzWzMlVNRDSHoN_Q',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ETYfSO-AU0b_z3PQyce1-g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '337 Princess St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['337 Princess St',
#                                                   'Kingston, ON K7L 3J4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 3J4'},
#                  'name': 'Gangnam Style',
#                  'phone': '+16135316087',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 19,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/gangnam-style-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'copper-penny-kingston',
#                  'categories': [{'alias': 'diners', 'title': 'Diners'}],
#                  'coordinates': {'latitude': 44.23208, 'longitude': -76.487},
#                  'display_phone': '+1 613-549-4257',
#                  'distance': 115.40522599396618,
#                  'id': 'FtxEsP46-pVf5Uxv-e0CKg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1ujOUhHa-TH2qEaZgZHvqQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '240 Princess St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['240 Princess St',
#                                                   'Kingston, ON K7L 1B2',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1B2'},
#                  'name': 'Copper Penny',
#                  'phone': '+16135494257',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 38,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/copper-penny-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'sushibar-da-kingston',
#                  'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#                                 {'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 44.2312328968303,
#                                  'longitude': -76.4810389280319},
#                  'display_phone': '+1 613-544-6278',
#                  'distance': 383.55335882596614,
#                  'id': 'c2l0WgScSoTHLHDGbnNvSA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j9Wj7Frsy1jRPBlB6Ng45g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '354 King Street E',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['354 King Street E',
#                                                   'Kingston, ON K7L 1A4',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1A4'},
#                  'name': 'Sushibar Da',
#                  'phone': '+16135446278',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 23,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sushibar-da-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'mango-restaurant-kingston',
#                  'categories': [{'alias': 'thai', 'title': 'Thai'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#                  'coordinates': {'latitude': 44.23205, 'longitude': -76.48448},
#                  'display_phone': '+1 613-549-3815',
#                  'distance': 95.1616434866395,
#                  'id': 'MIAVxRv5FML_Bpxc_ax6Bg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VVtA-mDvMAss_927A1sMcA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '161 Princess Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['161 Princess Street',
#                                                   'Kingston, ON K7L 1A9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1A9'},
#                  'name': 'Mango Restaurant',
#                  'phone': '+16135493815',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 42,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mango-restaurant-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'sushi-ya-zen-kingston',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 44.23155, 'longitude': -76.48042},
#                  'display_phone': '+1 613-530-2546',
#                  'distance': 412.8242845743358,
#                  'id': 'O4FsVtv0zaKkWWNYq39c7Q',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YhdVeaLhmqOSpU-Ey59w-g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '49 Princess Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['49 Princess Street',
#                                                   'Kingston, ON K7L 1A3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1A3'},
#                  'name': 'Sushi Ya Zen',
#                  'phone': '+16135302546',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 25,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sushi-ya-zen-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'royal-angkor-restaurant-kingston',
#                  'categories': [{'alias': 'cambodian', 'title': 'Cambodian'},
#                                 {'alias': 'thai', 'title': 'Thai'}],
#                  'coordinates': {'latitude': 44.2352, 'longitude': -76.49692},
#                  'display_phone': '+1 613-544-9268',
#                  'distance': 956.2928325831929,
#                  'id': 'TpScs_NHqwPnJrh6FCcYfQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_i-Ql9YyBmsadQYbumjt0A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '523 Princess Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['523 Princess Street',
#                                                   'Kingston, ON K7L 1C6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1C6'},
#                  'name': 'Royal Angkor Restaurant',
#                  'phone': '+16135449268',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 53,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/royal-angkor-restaurant-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'podonamu-kingston-2',
#                  'categories': [{'alias': 'korean', 'title': 'Korean'}],
#                  'coordinates': {'latitude': 44.23221, 'longitude': -76.4877},
#                  'display_phone': '+1 613-777-9949',
#                  'distance': 172.1438668545265,
#                  'id': '4YAltbYBYfgJ9PUD1GQWHw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c72-_5CASNgM27LJwtbJ2Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '264 Princess Street',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['264 Princess Street',
#                                                   'Kingston, ON K7L 1B5',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1B5'},
#                  'name': 'Podonamu',
#                  'phone': '+16137779949',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 30,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/podonamu-kingston-2?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'crave-coffee-house-and-bakery-kingston',
#                  'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                 {'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'cafes', 'title': 'Cafes'}],
#                  'coordinates': {'latitude': 44.23177, 'longitude': -76.48472},
#                  'display_phone': '+1 613-766-7766',
#                  'distance': 94.55274003521448,
#                  'id': 'fxYXwxhBl_UxIO5iyKSi6Q',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YOq_GAvPOJiFBu3NQaTPkQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '166 Princess Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['166 Princess Street',
#                                                   'Kingston, ON K7L 1B1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1B1'},
#                  'name': 'CRAVE Coffee House & Bakery',
#                  'phone': '+16137667766',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 31,
#                  'transactions': [],
# ...
#                  'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#                                 {'alias': 'fishnchips',
#                                  'title': 'Fish & Chips'}],
#                  'coordinates': {'latitude': 44.2288834,
#                                  'longitude': -76.4823581},
#                  'display_phone': '+1 613-542-0222',
#                  'distance': 463.30778191819803,
#                  'id': 'mJRtLaXJTYkAahDRh98SvA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KhdWGZ9Dzdp8GAbe6Qf8gw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '265 King Street E',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['265 King Street E',
#                                                   'Kingston, ON K7L 3B1',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 3B1'},
#                  'name': 'The Pilot House',
#                  'phone': '+16135420222',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 28,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-pilot-house-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'chois-roll-kingston',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 44.2325299,
#                                  'longitude': -76.48964},
#                  'display_phone': '+1 613-546-8800',
#                  'distance': 325.54130812944254,
#                  'id': 'IoF8NOQMD6wY7L_DwtCJIA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wfmwz7GYPWkvPYHzAIah7g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '326 Princess Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['326 Princess Street',
#                                                   'Kingston, ON K7L 1B6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1B6'},
#                  'name': "Choi's Roll",
#                  'phone': '+16135468800',
#                  'rating': 4.5,
#                  'review_count': 17,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/chois-roll-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'sunflower-chinese-restaurant-kingston',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 44.23249, 'longitude': -76.48524},
#                  'display_phone': '+1 613-507-2688',
#                  'distance': 32.94687037100091,
#                  'id': '_vsrz4fkyzpVUX2hOPd2TQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/za4gHpVkHCQaHD5Cr69VkA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '41 Montreal Street',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['41 Montreal Street',
#                                                   'Kingston, ON K7K 3E7',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7K 3E7'},
#                  'name': 'Sunflower Chinese Restaurant',
#                  'phone': '+16135072688',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 17,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sunflower-chinese-restaurant-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'meet-cuisine-kingston',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 44.233048,
#                                  'longitude': -76.4909549},
#                  'display_phone': '+1 613-531-8788',
#                  'distance': 440.33065071537965,
#                  'id': 'h1SlgY0tX1s22YRJmHMYkA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JhZIEqzZgiD_BpNkLyfHlA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '371 Princess St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['371 Princess St',
#                                                   'Kingston, ON K7L 1B9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1B9'},
#                  'name': 'Meet Cuisine',
#                  'phone': '+16135318788',
#                  'rating': 4.5,
#                  'review_count': 14,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/meet-cuisine-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'golden-rooster-delicatessen-kingston',
#                  'categories': [{'alias': 'delis', 'title': 'Delis'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 44.231634,
#                                  'longitude': -76.482977},
#                  'display_phone': '+1 613-542-5676',
#                  'distance': 223.13030599316417,
#                  'id': 'PEsyoXOTa2gDrqtfz5KZCA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0tyPfDPgYrX2EB9ZPWw7jQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '111 Princess Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['111 Princess Street',
#                                                   'Kingston, ON K7L 1A8',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1A8'},
#                  'name': 'Golden Rooster Delicatessen',
#                  'phone': '+16135425676',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 16,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/golden-rooster-delicatessen-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'white-mountain-kingston',
#                  'categories': [{'alias': 'icecream',
#                                  'title': 'Ice Cream & Frozen Yogurt'}],
#                  'coordinates': {'latitude': 44.22866, 'longitude': -76.48142},
#                  'display_phone': '',
#                  'distance': 525.7428872205517,
#                  'id': 'tfWERKDHLTQG8RUb8gLo5A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fbbqaXQwSQq29aqrHPRD8A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '176 Ontario St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['176 Ontario St',
#                                                   'Kingston, ON K7L 2Y8',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 2Y8'},
#                  'name': 'White Mountain',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 22,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/white-mountain-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'jack-astors-kingston-2',
#                  'categories': [{'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'},
#                                 {'alias': 'sportsbars', 'title': 'Sports Bars'},
#                                 {'alias': 'burgers', 'title': 'Burgers'}],
#                  'coordinates': {'latitude': 44.230688,
#                                  'longitude': -76.481343},
#                  'display_phone': '+1 613-549-1207',
#                  'distance': 385.6850233975976,
#                  'id': 'QmR5kjp6JEiAk9aGib7MsQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nOA8Q6MwlJH70sRZHAk7qg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '330 King Street East',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['330 King Street East',
#                                                   'Kingston, ON K7L 3B6',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 3B6'},
#                  'name': "Jack Astor's",
#                  'phone': '+16135491207',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 52,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/jack-astors-kingston-2?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'northern-chinese-barbeque-kingston',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 44.2320482506695,
#                                  'longitude': -76.4850468188524},
#                  'display_phone': '+1 613-531-8188',
#                  'distance': 54.76725244216586,
#                  'id': 'Kh1BvtW-0y3v5Qg9ys4SjQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_nCM3W_an1-iBcIbNUD7XA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '185 Princess Street',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['185 Princess Street',
#                                                   'Kingston, ON K7L 1A9',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1A9'},
#                  'name': 'Northern Chinese Barbeque',
#                  'phone': '+16135318188',
#                  'rating': 4.0,
#                  'review_count': 13,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/northern-chinese-barbeque-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'the-rustic-spud-restaurant-and-catering-kingston',
#                  'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#                                 {'alias': 'newcanadian',
#                                  'title': 'Canadian (New)'}],
#                  'coordinates': {'latitude': 44.2289647892159,
#                                  'longitude': -76.4861190319061},
#                  'display_phone': '+1 613-544-6969',
#                  'distance': 378.07259226999867,
#                  'id': 'ye81IV3eBiEq-LKKcunhzw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aQpi-9zdJ6UffS7TFgxqmA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '175 Bagot Street',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['175 Bagot Street',
#                                                   'Kingston, ON K7L 3E8',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 3E8'},
#                  'name': 'The Rustic Spud Restaurant & Catering',
#                  'phone': '+16135446969',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 19,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-rustic-spud-restaurant-and-catering-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'},
#                 {'alias': 'flavours-of-india-kingston',
#                  'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#                  'coordinates': {'latitude': 44.2340949162538,
#                                  'longitude': -76.4945512405134},
#                  'display_phone': '+1 613-536-3939',
#                  'distance': 739.537994752896,
#                  'id': 'ujA6OwDtt_dzpZWLHiZLqQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W5qaOodhNpHvz3GLD9S5Fw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '461 Princess Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kingston',
#                               'country': 'CA',
#                               'display_address': ['461 Princess Street',
#                                                   'Kingston, ON K7L 1C3',
#                                                   'Canada'],
#                               'state': 'ON',
#                               'zip_code': 'K7L 1C3'},
#                  'name': 'Flavours of India',
#                  'phone': '+16135363939',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 31,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/flavours-of-india-kingston?adjust_creative=eSQgpu45zIEXNdoOzbN4eA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=eSQgpu45zIEXNdoOzbN4eA'}],
#  'region': {'center': {'latitude': 44.232344187881836,
#                        'longitude': -76.48559630147832}},
#  'total': 156}

# %% [markdown]
# Again, we have a nested dictionary as the response. We can see that all POIs are kept inside a list within the dict key 'businesses'. Below, let's play around to find points of interest. In this case, our response is more rich in details, so we can select more information on each POI.

# %%
# number of POIs
#len(yelp_data['businesses'])

# POI Name
#poi_name = yelp_data['businesses'][0]['name']
#poi_name

# POI address
#poi_address = yelp_data['businesses'][0]['location']['address1']
#poi_address

# POI type
#poi_type = yelp_data['businesses'][0]['categories'][0]['title']
#poi_type

# POI rating
#poi_rating = yelp_data['businesses'][0]['rating']
#poi_rating

# POI price
#poi_price = yelp_data['businesses'][0]['price']
#poi_price

# %%
# Empty lists that we will add to the yelp_dict
y_names = []
y_addresses = []
y_types = []
y_ratings = []
y_prices = []

for i in range(len(yelp_data['businesses'])):
    # add POI name to names list
    y_names.append(yelp_data['businesses'][i]['name'])
    
    # add POI address to addresses list
    y_addresses.append(yelp_data['businesses'][i]['location']['address1'])
    
    # add POI type to types list
    y_types.append(yelp_data['businesses'][i]['categories'][0]['title'])
    
    # add POI rating to ratings list
    y_ratings.append(yelp_data['businesses'][i]['rating'])
    
    # add POI price info to prices list - using the same if statement to handle missing values
    if price_key in yelp_data['businesses'][i]:
        y_prices.append(yelp_data['businesses'][i]['price'])
    else:
        y_prices.append('NA')
        
print(y_names)
print(y_addresses)
print(y_types)
print(y_ratings)
print(y_prices)
# Out:
# ['Wooden Heads', 'Tango Nuevo', 'Pan Chancho Bakery', "Harper's", "Greco's Grill and Wine Bar", 'Wok-In Restaurant', 'Sima Sushi', 'NORTHSIDE Espresso + Kitchen', 'Mio Gelato', 'Amadeus Cafe', "Dianne's Fish Shack & Smokehouse", 'Chez Piggy Restaurant', "Sally's Roti Shop", 'Red House', 'Black Dog Tavern', 'Olivea', "Balzac's Coffee Roasters", 'Score Pizza', 'Ali Baba', 'Kame Sushi and Izakaya', 'The Cambodian Village', 'Geneva Crepe Cafe', 'Gangnam Style', 'Copper Penny', 'Sushibar Da', 'Mango Restaurant', 'Sushi Ya Zen', 'Royal Angkor Restaurant', 'Podonamu', 'CRAVE Coffee House & Bakery', "Peter's Place", 'The Keg Steakhouse + Bar - Kingston', 'Cambodiana Restaurant', 'Apsara Angkor', 'Thai House Cuisine', 'Atomica', 'i-tea', 'AquaTerra', "Pat's Restaurant", 'Casa', 'The Pilot House', "Choi's Roll", 'Sunflower Chinese Restaurant', 'Meet Cuisine', 'Golden Rooster Delicatessen', 'White Mountain', "Jack Astor's", 'Northern Chinese Barbeque', 'The Rustic Spud Restaurant & Catering', 'Flavours of India']
# ['192 Ontario Street', '331 King Street E', '44 Princess Street', '93 Princess Street', '167 Princess Street', '30 Montreal St', '66 Princess St', '281 Princess Street', '178 Ontario Street', '170 Princess Street', '195 Ontario Street', '68R Princess Street', '203 Wellington Street', '369 King Street E', '69 Brock Street', '39 Brock Street', '251 Princess Street', '91 Princess Street', '320 Princess St', '156 Division St', '347 King Street E', '297 Princess Street', '337 Princess St', '240 Princess St', '354 King Street E', '161 Princess Street', '49 Princess Street', '523 Princess Street', '264 Princess Street', '166 Princess Street', '34 Princess St', '300 King St E', '161 Brock Street', '189 Ontario Street', '183 Sydenham Street', '71 Brock Street', '296 Princess Street', '1 Johnson Street', '455 Princess Street', '35 Brock Street', '265 King Street E', '326 Princess Street', '41 Montreal Street', '371 Princess St', '111 Princess Street', '176 Ontario St', '330 King Street East', '185 Princess Street', '175 Bagot Street', '461 Princess Street']
# ['Pizza', 'Tapas/Small Plates', 'Bakeries', 'Burgers', 'Greek', 'Cambodian', 'Japanese', 'Cafes', 'Ice Cream & Frozen Yogurt', 'German', 'Seafood', 'Breakfast & Brunch', 'Caribbean', 'Gastropubs', 'French', 'Italian', 'Coffee Roasteries', 'Pizza', 'Persian/Iranian', 'Japanese', 'Cambodian', 'Creperies', 'Korean', 'Diners', 'Sushi Bars', 'Thai', 'Japanese', 'Cambodian', 'Korean', 'Coffee & Tea', 'American (Traditional)', 'Seafood', 'Cambodian', 'Thai', 'Thai', 'Italian', 'Bubble Tea', 'Canadian (New)', 'Cambodian', 'Italian', 'Pubs', 'Japanese', 'Chinese', 'Chinese', 'Delis', 'Ice Cream & Frozen Yogurt', 'Canadian (New)', 'Chinese', 'Cafes', 'Indian']
# [4.0, 4.5, 4.0, 4.0, 4.0, 5.0, 4.0, 4.5, 4.5, 4.5, 3.5, 3.5, 4.5, 4.0, 4.0, 4.0, 5.0, 4.5, 4.0, 4.5, 4.5, 3.5, 4.5, 4.0, 4.5, 3.5, 4.0, 4.0, 4.0, 3.5, 4.0, 4.0, 4.5, 4.0, 4.0, 3.5, 4.5, 3.5, 4.5, 4.0, 4.0, 4.5, 4.0, 4.5, 4.0, 4.0, 3.5, 4.0, 4.0, 4.0]
# ['$$', '$$$', '$$', '$$', '$$', '$', '$$', '$$', '$$', '$$', '$$', '$$$', '$', '$$', '$$$', '$$$', '$$', 'NA', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$$$', '$$', '$$', '$$', '$$', '$', '$$', '$$', '$$$', '$$', 'NA', '$$', 'NA', '$', '$$', '$$', 'NA', '$$', '$$']

# %%
# Create a dict with the lists
yelp_dict = {
    'Name': y_names,
    'Address': y_addresses,
    'Type': y_types,
    'Rating': y_ratings,
    'Price': y_prices
}

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# create a dataframe from the fsd_dict variable
yelp_df = pd.DataFrame(yelp_dict)
yelp_df
# Out:
#                                      Name                Address  \
# 0                            Wooden Heads     192 Ontario Street
# 1                             Tango Nuevo      331 King Street E
# 2                      Pan Chancho Bakery     44 Princess Street
# 3                                Harper's     93 Princess Street
# 4              Greco's Grill and Wine Bar    167 Princess Street
# 5                       Wok-In Restaurant         30 Montreal St
# 6                              Sima Sushi         66 Princess St
# 7            NORTHSIDE Espresso + Kitchen    281 Princess Street
# 8                              Mio Gelato     178 Ontario Street
# 9                            Amadeus Cafe    170 Princess Street
# 10       Dianne's Fish Shack & Smokehouse     195 Ontario Street
# 11                  Chez Piggy Restaurant    68R Princess Street
# 12                      Sally's Roti Shop  203 Wellington Street
# 13                              Red House      369 King Street E
# 14                       Black Dog Tavern        69 Brock Street
# 15                                 Olivea        39 Brock Street
# 16               Balzac's Coffee Roasters    251 Princess Street
# 17                            Score Pizza     91 Princess Street
# 18                               Ali Baba        320 Princess St
# 19                 Kame Sushi and Izakaya        156 Division St
# 20                  The Cambodian Village      347 King Street E
# 21                      Geneva Crepe Cafe    297 Princess Street
# 22                          Gangnam Style        337 Princess St
# 23                           Copper Penny        240 Princess St
# 24                            Sushibar Da      354 King Street E
# 25                       Mango Restaurant    161 Princess Street
# 26                           Sushi Ya Zen     49 Princess Street
# 27                Royal Angkor Restaurant    523 Princess Street
# 28                               Podonamu    264 Princess Street
# 29            CRAVE Coffee House & Bakery    166 Princess Street
# 30                          Peter's Place         34 Princess St
# 31    The Keg Steakhouse + Bar - Kingston          300 King St E
# 32                  Cambodiana Restaurant       161 Brock Street
# 33                          Apsara Angkor     189 Ontario Street
# 34                     Thai House Cuisine    183 Sydenham Street
# 35                                Atomica        71 Brock Street
# 36                                  i-tea    296 Princess Street
# 37                              AquaTerra       1 Johnson Street
# 38                       Pat's Restaurant    455 Princess Street
# 39                                   Casa        35 Brock Street
# 40                        The Pilot House      265 King Street E
# 41                            Choi's Roll    326 Princess Street
# 42           Sunflower Chinese Restaurant     41 Montreal Street
# 43                           Meet Cuisine        371 Princess St
# 44            Golden Rooster Delicatessen    111 Princess Street
# 45                         White Mountain         176 Ontario St
# 46                           Jack Astor's   330 King Street East
# 47              Northern Chinese Barbeque    185 Princess Street
# 48  The Rustic Spud Restaurant & Catering       175 Bagot Street
# 49                      Flavours of India    461 Princess Street
#
#                          Type  Rating Price
# 0                       Pizza     4.0    $$
# 1          Tapas/Small Plates     4.5   $$$
# 2                    Bakeries     4.0    $$
# 3                     Burgers     4.0    $$
# 4                       Greek     4.0    $$
# 5                   Cambodian     5.0     $
# 6                    Japanese     4.0    $$
# 7                       Cafes     4.5    $$
# 8   Ice Cream & Frozen Yogurt     4.5    $$
# 9                      German     4.5    $$
# 10                    Seafood     3.5    $$
# 11         Breakfast & Brunch     3.5   $$$
# 12                  Caribbean     4.5     $
# 13                 Gastropubs     4.0    $$
# 14                     French     4.0   $$$
# 15                    Italian     4.0   $$$
# 16          Coffee Roasteries     5.0    $$
# 17                      Pizza     4.5    NA
# 18            Persian/Iranian     4.0    $$
# 19                   Japanese     4.5    $$
# 20                  Cambodian     4.5    $$
# 21                  Creperies     3.5    $$
# 22                     Korean     4.5    $$
# 23                     Diners     4.0    $$
# 24                 Sushi Bars     4.5    $$
# 25                       Thai     3.5    $$
# 26                   Japanese     4.0    $$
# 27                  Cambodian     4.0    $$
# 28                     Korean     4.0    $$
# 29               Coffee & Tea     3.5    $$
# 30     American (Traditional)     4.0    $$
# 31                    Seafood     4.0   $$$
# 32                  Cambodian     4.5    $$
# 33                       Thai     4.0    $$
# 34                       Thai     4.0    $$
# 35                    Italian     3.5    $$
# 36                 Bubble Tea     4.5     $
# 37             Canadian (New)     3.5    $$
# 38                  Cambodian     4.5    $$
# 39                    Italian     4.0   $$$
# 40                       Pubs     4.0    $$
# 41                   Japanese     4.5    NA
# 42                    Chinese     4.0    $$
# 43                    Chinese     4.5    NA
# 44                      Delis     4.0     $
# 45  Ice Cream & Frozen Yogurt     4.0    $$
# 46             Canadian (New)     3.5    $$
# 47                    Chinese     4.0    NA
# 48                      Cafes     4.0    $$
# 49                     Indian     4.0    $$

# %%
# Explore the data by grouping based on venue type
yelp_df.groupby('Type').agg(n_venues = ('Type', 'count')).nlargest(5, 'n_venues', keep='all')
# Out:
#            n_venues
# Type
# Cambodian         5
# Japanese          4
# Chinese           3
# Italian           3
# Thai              3

# %% [markdown]
# # Google (stretch)

# %% [markdown]
# Use the same process as the first two APIs

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
connection = sqlite3.connect("/home/eduardo/lighthouse-data-notes/mini-project-II/data/miniproject2_db.sqlite")

# %%
# First, let's add the fsq_df to our database
# Create connection to the database
connection = sqlite3.connect("/home/eduardo/lighthouse-data-notes/mini-project-II/data/miniproject2_db.sqlite")

# Push the dataframe to sql 
fsq_df.to_sql("fsq", connection, if_exists="replace", index=False)

# Close connection with the database when done
#connection.close()
# Out:
# 50

# %%
# Now, let's add the yelp_df to our database
# Create connection to the database
connection = sqlite3.connect("/home/eduardo/lighthouse-data-notes/mini-project-II/data/miniproject2_db.sqlite")

# Push the dataframe to sql 
yelp_df.to_sql("yelp", connection, if_exists="replace", index=False)

# Close connection with the database when done
#connection.close()
# Out:
# 50

# %%
# To obtain information from our database, we will use pandas .read_sql() method
# First, let's test to see if our tables were created correctly
pd.read_sql('SELECT * FROM fsq', connection)
# Out:
#                               Name            Address  \
# 0           Minotaur Games & Gifts    165 Princess St
# 1                        Dollarama    176 Princess St
# 2      Crave Coffee House & Bakery    166 Princess St
# 3                        Menchie's    241 Princess St
# 4                  Stone City Ales    275 Princess St
# 5                     Amadeus Cafe    170 Princess St
# 6                           Hwa-Ki    269 Princess St
# 7               The Screening Room    120 Princess St
# 8                  Balzac's Coffee    251 Princess St
# 9          Grecos Grill & Wine Bar    167 Princess St
# 10             Lululemon Athletica    270 Princess St
# 11              Shoppers Drug Mart    136 Princess St
# 12                Urban Outfitters    207 Princess St
# 13    NORTHSIDE espresso + kitchen    281 Princess St
# 14                        Harper's     93 Princess St
# 15     Golden Rooster Delicatessen    111 Princess St
# 16                    Copper Penny    240 Princess St
# 17             Kingston Frameworks    198 Princess St
# 18                     Plaza Hotel     46 Montreal St
# 19                     Ta Ke Sushi    120 Princess St
# 20                       Starbucks     95 Princess St
# 21                 Racquet Science     332A Barrie St
# 22            Megalo's Restaurants    226 Princess St
# 23       Union Kitchen + Cocktails    184 Princess St
# 24       Northern Chinese Barbeque    185 Princess St
# 25  Mango Thai & Pan-Asian Cuisine    161 Princess St
# 26               True North Tattoo       159 Queen St
# 27                     Score Pizza     91 Princess St
# 28                       The Alibi    293 Princess St
# 29                      The Toucan     76 Princess St
# 30                 Saigon Delights       272 Bagot St
# 31                      Chez Piggy   68R Princess Ave
# 32               Geneva Crepe Cafe    297 Princess St
# 33           Andrei Master Tailors    170 Princess St
# 34                            CIBC       164 Brock St
# 35                   Le Chien Noir        69 Brock St
# 36               Graham's Pharmacy    168 Princess St
# 37                      Sima Sushi     66 Princess St
# 38                     Tango Nuevo      331 King St E
# 39     The Iron Duke on Wellington  207 Wellington St
# 40       St Paul's Anglican Church       137 Queen St
# 41         Sir John's Public House      343 King St E
# 42              Pan Chancho Bakery     44 Princess St
# 43                        Musiikki        73 Brock St
# 44                       Overstock    169 Princess St
# 45                 The Queen's Inn       125 Brock St
# 46           Cambodiana Restaurant       161 Brock St
# 47                      Novel Idea    156 Princess St
# 48   Cooke's Fine Foods and Coffee        61 Brock St
# 49             Kingston Online Svc       303 Bagot St
#
#                              Type Rating Price  Popularity
# 0                      Gift Store    8.4    NA        0.86
# 1                  Discount Store    7.3    NA        0.93
# 2                          Bakery    8.0     1        0.96
# 3              Frozen Yogurt Shop    7.7     1        0.82
# 4                         Brewery    9.0     2        0.93
# 5                            Café    6.9     2        0.92
# 6                Sushi Restaurant    7.9     2        0.29
# 7             Indie Movie Theater    8.3    NA        0.87
# 8                            Café    7.3     1        0.94
# 9                           Diner    6.6     2        0.91
# 10          Sporting Goods Retail    7.6    NA        0.93
# 11                      Drugstore    7.2    NA        0.97
# 12                 Clothing Store    5.8    NA        0.91
# 13            Dining and Drinking    7.6     1        0.85
# 14                     Restaurant    8.3     2        0.89
# 15                        Caterer    7.5     1        0.94
# 16            American Restaurant    6.5     2        0.90
# 17                    Art Gallery     NA    NA        0.84
# 18                          Hotel     NA     3        0.78
# 19               Sushi Restaurant    7.3     3        0.22
# 20                    Coffee Shop    7.9     1        0.94
# 21                  Bicycle Store     NA    NA        0.18
# 22        New American Restaurant    5.9     2        0.91
# 23                     Night Club     NA     3        0.93
# 24             Chinese Restaurant     NA     1        0.89
# 25            American Restaurant    6.0     2        0.87
# 26                  Tattoo Parlor     NA    NA        0.86
# 27                       Pizzeria    7.9     1        0.85
# 28                            Bar    7.4     2        0.82
# 29                            Pub    8.3     1        0.94
# 30             Chinese Restaurant    6.3     2        0.88
# 31                          Diner    8.4     4        0.93
# 32                         Bistro    7.4     1        0.91
# 33                         Tailor     NA    NA        0.07
# 34                           Bank    6.5    NA        0.88
# 35                     Restaurant    8.1     1        0.89
# 36                      Drugstore     NA    NA        0.75
# 37               Sushi Restaurant    8.1     2        0.90
# 38                       Wine Bar    8.9     3        0.93
# 39                            Pub    7.1     1        0.90
# 40                         Church     NA    NA        0.94
# 41                            Pub    8.4     1        0.85
# 42                         Bakery    9.1     2        0.97
# 43          Performing Arts Venue    7.5    NA        0.85
# 44                  Women's Store     NA    NA        0.17
# 45                          Hotel    6.4     1        0.84
# 46                          Diner     NA     2        0.52
# 47                      Bookstore     NA    NA        0.83
# 48  Cafes, Coffee, and Tea Houses    7.7    NA        0.88
# 49        Computer Repair Service     NA    NA        0.44

# %%
# Testing the yelp table
pd.read_sql('SELECT * FROM yelp', connection)
# Out:
#                                      Name                Address  \
# 0                            Wooden Heads     192 Ontario Street
# 1                             Tango Nuevo      331 King Street E
# 2                      Pan Chancho Bakery     44 Princess Street
# 3                                Harper's     93 Princess Street
# 4              Greco's Grill and Wine Bar    167 Princess Street
# 5                       Wok-In Restaurant         30 Montreal St
# 6                              Sima Sushi         66 Princess St
# 7            NORTHSIDE Espresso + Kitchen    281 Princess Street
# 8                              Mio Gelato     178 Ontario Street
# 9                            Amadeus Cafe    170 Princess Street
# 10       Dianne's Fish Shack & Smokehouse     195 Ontario Street
# 11                  Chez Piggy Restaurant    68R Princess Street
# 12                      Sally's Roti Shop  203 Wellington Street
# 13                              Red House      369 King Street E
# 14                       Black Dog Tavern        69 Brock Street
# 15                                 Olivea        39 Brock Street
# 16               Balzac's Coffee Roasters    251 Princess Street
# 17                            Score Pizza     91 Princess Street
# 18                               Ali Baba        320 Princess St
# 19                 Kame Sushi and Izakaya        156 Division St
# 20                  The Cambodian Village      347 King Street E
# 21                      Geneva Crepe Cafe    297 Princess Street
# 22                          Gangnam Style        337 Princess St
# 23                           Copper Penny        240 Princess St
# 24                            Sushibar Da      354 King Street E
# 25                       Mango Restaurant    161 Princess Street
# 26                           Sushi Ya Zen     49 Princess Street
# 27                Royal Angkor Restaurant    523 Princess Street
# 28                               Podonamu    264 Princess Street
# 29            CRAVE Coffee House & Bakery    166 Princess Street
# 30                          Peter's Place         34 Princess St
# 31    The Keg Steakhouse + Bar - Kingston          300 King St E
# 32                  Cambodiana Restaurant       161 Brock Street
# 33                          Apsara Angkor     189 Ontario Street
# 34                     Thai House Cuisine    183 Sydenham Street
# 35                                Atomica        71 Brock Street
# 36                                  i-tea    296 Princess Street
# 37                              AquaTerra       1 Johnson Street
# 38                       Pat's Restaurant    455 Princess Street
# 39                                   Casa        35 Brock Street
# 40                        The Pilot House      265 King Street E
# 41                            Choi's Roll    326 Princess Street
# 42           Sunflower Chinese Restaurant     41 Montreal Street
# 43                           Meet Cuisine        371 Princess St
# 44            Golden Rooster Delicatessen    111 Princess Street
# 45                         White Mountain         176 Ontario St
# 46                           Jack Astor's   330 King Street East
# 47              Northern Chinese Barbeque    185 Princess Street
# 48  The Rustic Spud Restaurant & Catering       175 Bagot Street
# 49                      Flavours of India    461 Princess Street
#
#                          Type  Rating Price
# 0                       Pizza     4.0    $$
# 1          Tapas/Small Plates     4.5   $$$
# 2                    Bakeries     4.0    $$
# 3                     Burgers     4.0    $$
# 4                       Greek     4.0    $$
# 5                   Cambodian     5.0     $
# 6                    Japanese     4.0    $$
# 7                       Cafes     4.5    $$
# 8   Ice Cream & Frozen Yogurt     4.5    $$
# 9                      German     4.5    $$
# 10                    Seafood     3.5    $$
# 11         Breakfast & Brunch     3.5   $$$
# 12                  Caribbean     4.5     $
# 13                 Gastropubs     4.0    $$
# 14                     French     4.0   $$$
# 15                    Italian     4.0   $$$
# 16          Coffee Roasteries     5.0    $$
# 17                      Pizza     4.5    NA
# 18            Persian/Iranian     4.0    $$
# 19                   Japanese     4.5    $$
# 20                  Cambodian     4.5    $$
# 21                  Creperies     3.5    $$
# 22                     Korean     4.5    $$
# 23                     Diners     4.0    $$
# 24                 Sushi Bars     4.5    $$
# 25                       Thai     3.5    $$
# 26                   Japanese     4.0    $$
# 27                  Cambodian     4.0    $$
# 28                     Korean     4.0    $$
# 29               Coffee & Tea     3.5    $$
# 30     American (Traditional)     4.0    $$
# 31                    Seafood     4.0   $$$
# 32                  Cambodian     4.5    $$
# 33                       Thai     4.0    $$
# 34                       Thai     4.0    $$
# 35                    Italian     3.5    $$
# 36                 Bubble Tea     4.5     $
# 37             Canadian (New)     3.5    $$
# 38                  Cambodian     4.5    $$
# 39                    Italian     4.0   $$$
# 40                       Pubs     4.0    $$
# 41                   Japanese     4.5    NA
# 42                    Chinese     4.0    $$
# 43                    Chinese     4.5    NA
# 44                      Delis     4.0     $
# 45  Ice Cream & Frozen Yogurt     4.0    $$
# 46             Canadian (New)     3.5    $$
# 47                    Chinese     4.0    NA
# 48                      Cafes     4.0    $$
# 49                     Indian     4.0    $$

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
# To get the top 10 restaurants, we will need an ORDER BY in our query. This will be done with each table.
# Yelp table
query = '''
    SELECT
        y.Name, 
        y.Rating
    FROM
        yelp AS y
    ORDER BY 
        y.Rating DESC
    LIMIT
        10
'''

pd.read_sql(query, connection)
# Out:
#                            Name  Rating
# 0             Wok-In Restaurant     5.0
# 1      Balzac's Coffee Roasters     5.0
# 2                   Tango Nuevo     4.5
# 3  NORTHSIDE Espresso + Kitchen     4.5
# 4                    Mio Gelato     4.5
# 5                  Amadeus Cafe     4.5
# 6             Sally's Roti Shop     4.5
# 7                   Score Pizza     4.5
# 8        Kame Sushi and Izakaya     4.5
# 9         The Cambodian Village     4.5

# %%
# FSQ table - remove missing ('NA') rating information
query = '''
    SELECT
        f.Name, 
        f.Rating
    FROM
        fsq AS f
    WHERE
        f.Rating IS NOT 'NA'
    ORDER BY 
        f.Rating DESC
    LIMIT
        10
'''

pd.read_sql(query, connection)
# Out:
#                       Name Rating
# 0       Pan Chancho Bakery    9.1
# 1          Stone City Ales    9.0
# 2              Tango Nuevo    8.9
# 3   Minotaur Games & Gifts    8.4
# 4               Chez Piggy    8.4
# 5  Sir John's Public House    8.4
# 6       The Screening Room    8.3
# 7                 Harper's    8.3
# 8               The Toucan    8.3
# 9            Le Chien Noir    8.1

# %% [markdown]
# # Travelling Salesman Problem (stretch)

# %% [markdown]
# If you have time, follow the steps in the [ortools tutorial](https://developers.google.com/optimization/routing/tsp) using Google's [Directions API](https://developers.google.com/maps/documentation/directions/start).
